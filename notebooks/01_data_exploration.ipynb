# %% [markdown]
# # Flood Data Exploration
#
# This notebook explores the hydrological data for flood prediction.
#
# ## Objectives:
# 1. Load and understand the dataset
# 2. Analyze temporal patterns
# 3. Identify correlations
# 4. Detect anomalies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('../data/processed/flood_data.csv')
print(f"Dataset shape: {data.shape}")
data.head()
